# %% [markdown]
# # OS Credential Dumping: NTDS - T1003.003 TH Notebook

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from datetime import timedelta 
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import pandas as pd

# %%
spark = SparkSession.builder \
    .appName("HELK Reader") \
    .master("spark://helk-spark-master:7077") \
    .config("spark.executor.memory","5g") \
    .enableHiveSupport() \
    .getOrCreate()
spark.conf.set("spark.sql.caseSensitive", "true")

# %%
pd.set_option('display.max_columns', 50)
pd.set_option("max_colwidth", None)

# %%
es_reader = (spark.read.format("org.elasticsearch.spark.sql")
    .option("inferSchema", "true")
    .option("es.nodes","")
    .option("es.nodes.wan.only","true")
    .option("es.net.http.auth.user","elastic"))

# %%
sysmon_df = es_reader.load("logs-endpoint-winevent-sysmon-2020.04.12")
app_df = es_reader.load("logs-endpoint-winevent-application-2020.04.12")

# %%
sysmon_df.createOrReplaceTempView("sysmon_events")
app_df.createOrReplaceTempView("application_events")

# %% [markdown]
# ## Triger 1 - Find ntdsutil.exe execution

# %%
ntdsustil_log = sysmon_df.where((sysmon_df.process_name == "ntdsutil.exe") & (sysmon_df.event_id == '1')).select(F.col("process_name"),F.col("process_guid"),F.col("process_path"),F.col("process_command_line"),F.col("process_parent_name"),F.col("process_parent_guid"),F.col("process_parent_command_line"),F.col("user_name"),F.col("user_account"),F.col("user_logon_guid"),F.col("host_name"))

# %%
ntdsustil_log.toPandas()
# Out:
#    process_name                          process_guid  \
# 0  ntdsutil.exe  CEEB91CE-FC86-5E92-0000-001079D2F31C
# 1  ntdsutil.exe  CEEB91CE-FC83-5E92-0000-00105F94F31C
# 2  ntdsutil.exe  CEEB91CE-FC83-5E92-0000-00105CA6F31C
#
#                        process_path  \
# 0  c:\windows\system32\ntdsutil.exe
# 1  c:\windows\system32\ntdsutil.exe
# 2  c:\windows\system32\ntdsutil.exe
#
#                                                               process_command_line  \
# 0  "c:\windows\system32\ntdsutil.exe"  "ac i ntds" "ifm" "create full c:\temp" q q
# 1                            ntdsutil  "ac i ntds" "ifm" "create full c:\temp" q q
# 2  "c:\windows\system32\ntdsutil.exe"  "ac i ntds" "ifm" "create full c:\temp" q q
#
#   process_parent_name                   process_parent_guid  \
# 0             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
# 1             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
# 2             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
#
#       process_parent_command_line user_name      user_account  \
# 0  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
# 1  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
# 2  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
#
#                         user_logon_guid         host_name
# 0  CEEB91CE-FB90-5E92-0000-00205E55E91C  dc1.research.com
# 1  CEEB91CE-FB90-5E92-0000-00207F55E91C  dc1.research.com
# 2  CEEB91CE-FB90-5E92-0000-00207F55E91C  dc1.research.com

# %%
event_11_sysmon = sysmon_df.where(sysmon_df.event_id == '11').groupby(sysmon_df.process_guid, sysmon_df.host_name).agg(F.collect_set("file_name").alias("files_created"),F.min('@timestamp').alias("min_time_files"),F.max('@timestamp').alias("max_time_files"))

# %%
event_12_sysmon = sysmon_df.where(sysmon_df.event_id == '12').groupby(sysmon_df.process_guid, sysmon_df.host_name).agg(F.collect_set("registry_key_path").alias("registry_createdDeleted"),F.min('@timestamp').alias("mintime_registry_createdDeleted"),F.max('@timestamp').alias("maxtime_registry_createdDeleted"))

# %%
event_13_sysmon = sysmon_df.where(sysmon_df.event_id == '13').groupby(sysmon_df.process_guid, sysmon_df.host_name).agg(F.collect_set("registry_key_path").alias("registry_valueSet"),F.min('@timestamp').alias("mintime_registry_valueSet"),F.max('@timestamp').alias("maxtime_registry_valueSet"))

# %%
event_14_sysmon = sysmon_df.where(sysmon_df.event_id == '14').groupby(sysmon_df.process_guid, sysmon_df.host_name).agg(F.collect_set("registry_key_path").alias("registry_rename"),F.min('@timestamp').alias("mintime_registry_rename"),F.max('@timestamp').alias("maxtime_registry_rename"))

# %%
ntdsustil_log_join_1 = event_11_sysmon.join(ntdsustil_log, on = ['process_guid','host_name'] ,how='right')

# %%
ntdsustil_log_join_2 = event_12_sysmon.join(ntdsustil_log_join_1, on= ['process_guid','host_name'] ,how='right')

# %%
ntdsustil_log_join_3 = event_13_sysmon.join(ntdsustil_log_join_2,on= ['process_guid','host_name'] ,how='right')

# %%
ntdsustil_log_join_4 = event_14_sysmon.join(ntdsustil_log_join_3,on= ['process_guid','host_name']  ,how='right')

# %%
ntdsustil_log_join_4.toPandas()
# Out:
#                            process_guid         host_name registry_rename  \
# 0  CEEB91CE-FC83-5E92-0000-00105F94F31C  dc1.research.com            None
# 1  CEEB91CE-FC83-5E92-0000-00105CA6F31C  dc1.research.com            None
# 2  CEEB91CE-FC86-5E92-0000-001079D2F31C  dc1.research.com            None
#
#   mintime_registry_rename maxtime_registry_rename  \
# 0                     NaT                     NaT
# 1                     NaT                     NaT
# 2                     NaT                     NaT
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 registry_valueSet  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None
# 2  [HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\GETSTATE (Enter), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\PREPAREBACKUP (Leave), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\IDENTIFY (Leave), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\DOSNAPSHOT (Leave), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\PREPAREBACKUP (Enter), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\GETSTATE (Leave), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\BACKUPCOMPLETE (Leave), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\IDENTIFY (Enter), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\BACKUPCOMPLETE (Enter), HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher\DOSNAPSHOT (Enter)]
#
#   mintime_registry_valueSet maxtime_registry_valueSet  \
# 0                       NaT                       NaT
# 1                       NaT                       NaT
# 2   2020-04-12 11:33:27.462   2020-04-12 11:33:37.988
#
#                                                                                                       registry_createdDeleted  \
# 0                                                                                                                        None
# 1                                                                                                                        None
# 2  [HKLM\System\CurrentControlSet\Services\VSS\Diag\VssapiPublisher, HKLM\System\CurrentControlSet\Services\Tcpip\Parameters]
#
#   mintime_registry_createdDeleted maxtime_registry_createdDeleted  \
# 0                             NaT                             NaT
# 1                             NaT                             NaT
# 2         2020-04-12 11:33:26.836         2020-04-12 11:33:26.968
#
#                                                                                                                                                                                                                files_created  \
# 0                                                                                                                                                                                                                       None
# 1                                                                                                                                                                                                                       None
# 2  [c:\temp\active directory\ntds.dit, c:\temp\active directory, c:\temp\registry\security, c:\$snap_202004121433_volumec$, c:\temp\registry\system, c:\temp\registry, c:\temp, c:\users\spadmin\appdata\local\temp\tmp.edb]
#
#            min_time_files          max_time_files  process_name  \
# 0                     NaT                     NaT  ntdsutil.exe
# 1                     NaT                     NaT  ntdsutil.exe
# 2 2020-04-12 11:33:27.244 2020-04-12 11:33:44.461  ntdsutil.exe
#
#                        process_path  \
# 0  c:\windows\system32\ntdsutil.exe
# 1  c:\windows\system32\ntdsutil.exe
# 2  c:\windows\system32\ntdsutil.exe
#
#                                                               process_command_line  \
# 0                            ntdsutil  "ac i ntds" "ifm" "create full c:\temp" q q
# 1  "c:\windows\system32\ntdsutil.exe"  "ac i ntds" "ifm" "create full c:\temp" q q
# 2  "c:\windows\system32\ntdsutil.exe"  "ac i ntds" "ifm" "create full c:\temp" q q
#
#   process_parent_name                   process_parent_guid  \
# 0             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
# 1             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
# 2             cmd.exe  CEEB91CE-FC52-5E92-0000-00101647F31C
#
#       process_parent_command_line user_name      user_account  \
# 0  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
# 1  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
# 2  "c:\windows\system32\cmd.exe"    spadmin  research\spadmin
#
#                         user_logon_guid
# 0  CEEB91CE-FB90-5E92-0000-00207F55E91C
# 1  CEEB91CE-FB90-5E92-0000-00207F55E91C
# 2  CEEB91CE-FB90-5E92-0000-00205E55E91C

# %% [markdown]
# ## Triger 2 -Find NTDS copies on  local disk

# %%
ntds_dc_app_log = spark.sql(
    '''
    SELECT host_name,param1,param5 
    FROM application_events 
    WHERE (event_id in (325, 326, 327)) and param1 LIKE "%NTDS" or param5 LIKE "%ntds.dit"
    ''')

# %%
ntds_dc_app_log.toPandas()
# Out:
#           host_name param1  \
# 0  dc1.research.com  lsass
# 1  dc1.research.com   NTDS
# 2  dc1.research.com   NTDS
# 3  dc1.research.com   NTDS
# 4  dc1.research.com   NTDS
#
#                                                                   param5
# 0  \\?\GLOBALROOT\Device\HarddiskVolumeShadowCopy1\Windows\NTDS\ntds.dit
# 1                   C:\$SNAP_202004121433_VOLUMEC$\Windows\NTDS\ntds.dit
# 2                                      c:\temp\Active Directory\ntds.dit
# 3                                      c:\temp\Active Directory\ntds.dit
# 4                   C:\$SNAP_202004121433_VOLUMEC$\Windows\NTDS\ntds.dit

# %% [markdown]
# ## Triger 3 - Find vssadmin.exe execution , Volume Shadow Copy activity

# %%
VSSadmin_sysmon = sysmon_df.filter( (sysmon_df.process_name == "vssadmin.exe") &
                                   (sysmon_df.event_id == '1') &
                                   ((sysmon_df.process_command_line.contains('create')) | (sysmon_df.process_command_line.contains('delete')))).select(F.col("process_name"),F.col("process_guid"),F.col("process_path"),F.col("process_command_line"),F.col("process_parent_name"),F.col("process_parent_guid"),F.col("process_parent_command_line"),F.col("user_name"),F.col("user_account"),F.col("user_logon_guid"),F.col("host_name"))

# %%
VSSadmin_sysmon.toPandas()
# Out:
#    process_name                          process_guid  \
# 0  vssadmin.exe  CEEB91CE-0908-5E93-0000-0010214C1E1D
# 1  vssadmin.exe  CEEB91CE-0898-5E93-0000-001022D4181D
# 2  vssadmin.exe  CEEB91CE-08AF-5E93-0000-001067CA1D1D
#
#                        process_path  \
# 0  c:\windows\system32\vssadmin.exe
# 1  c:\windows\system32\vssadmin.exe
# 2  c:\windows\system32\vssadmin.exe
#
#                                                       process_command_line  \
# 0  vssadmin  delete shadows /shadow={f6217010-5c41-48ae-b37c-41b40311af09}
# 1                                          vssadmin  create shadow /for=c:
# 2                                          vssadmin  create shadow /for=c:
#
#   process_parent_name                   process_parent_guid  \
# 0             cmd.exe  CEEB91CE-08AA-5E93-0000-0010D9BA1D1D
# 1             cmd.exe  CEEB91CE-0796-5E93-0000-0010F393131D
# 2             cmd.exe  CEEB91CE-08AA-5E93-0000-0010D9BA1D1D
#
#       process_parent_command_line user_name      user_account  \
# 0  "c:\windows\system32\cmd.exe"    sdadmin  research\sdadmin
# 1  "c:\windows\system32\cmd.exe"    sdadmin  research\sdadmin
# 2  "c:\windows\system32\cmd.exe"    sdadmin  research\sdadmin
#
#                         user_logon_guid         host_name
# 0  CEEB91CE-05D9-5E93-0000-0020684D031D  dc1.research.com
# 1  CEEB91CE-05D9-5E93-0000-0020DA4E031D  dc1.research.com
# 2  CEEB91CE-05D9-5E93-0000-0020684D031D  dc1.research.com

# %%
VSSadmin_join_1 = event_11_sysmon.join(VSSadmin_sysmon, on = ['process_guid','host_name'] ,how='right')

# %%
VSSadmin_join_2 = event_12_sysmon.join(VSSadmin_join_1, on= ['process_guid','host_name'] ,how='right')

# %%
VSSadmin_join_3 = event_13_sysmon.join(VSSadmin_join_2, on= ['process_guid','host_name'] ,how='right')

# %%
VSSadmin_join_4 = event_14_sysmon.join(VSSadmin_join_3, on= ['process_guid','host_name']  ,how='right')

# %%
final_results = VSSadmin_join_4.toPandas()

# %%
final_results[["process_guid","host_name","process_name","process_path","process_command_line","process_parent_name","process_parent_guid","process_parent_command_line","user_account","user_logon_guid","registry_rename","registry_valueSet","registry_createdDeleted","files_created","registry_createdDeleted","registry_valueSet","registry_createdDeleted","files_created"]]
# Out:
#                            process_guid         host_name  process_name  \
# 0  CEEB91CE-0898-5E93-0000-001022D4181D  dc1.research.com  vssadmin.exe
# 1  CEEB91CE-08AF-5E93-0000-001067CA1D1D  dc1.research.com  vssadmin.exe
# 2  CEEB91CE-0908-5E93-0000-0010214C1E1D  dc1.research.com  vssadmin.exe
#
#                        process_path  \
# 0  c:\windows\system32\vssadmin.exe
# 1  c:\windows\system32\vssadmin.exe
# 2  c:\windows\system32\vssadmin.exe
#
#                                                       process_command_line  \
# 0                                          vssadmin  create shadow /for=c:
# 1                                          vssadmin  create shadow /for=c:
# 2  vssadmin  delete shadows /shadow={f6217010-5c41-48ae-b37c-41b40311af09}
#
#   process_parent_name                   process_parent_guid  \
# 0             cmd.exe  CEEB91CE-0796-5E93-0000-0010F393131D
# 1             cmd.exe  CEEB91CE-08AA-5E93-0000-0010D9BA1D1D
# 2             cmd.exe  CEEB91CE-08AA-5E93-0000-0010D9BA1D1D
#
#       process_parent_command_line      user_account  \
# 0  "c:\windows\system32\cmd.exe"   research\sdadmin
# 1  "c:\windows\system32\cmd.exe"   research\sdadmin
# 2  "c:\windows\system32\cmd.exe"   research\sdadmin
#
#                         user_logon_guid registry_rename registry_valueSet  \
# 0  CEEB91CE-05D9-5E93-0000-0020DA4E031D            None              None
# 1  CEEB91CE-05D9-5E93-0000-0020684D031D            None              None
# 2  CEEB91CE-05D9-5E93-0000-0020684D031D            None              None
#
#   registry_createdDeleted files_created registry_createdDeleted  \
# 0                    None          None                    None
# 1                    None          None                    None
# 2                    None          None                    None
#
#   registry_valueSet registry_createdDeleted files_created
# 0              None                    None          None
# 1              None                    None          None
# 2              None                    None          None
